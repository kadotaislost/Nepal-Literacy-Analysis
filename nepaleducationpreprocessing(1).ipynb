# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/drive/MyDrive/dataset/Indv17_PopulationByLiteracyStatus.csv")

# %%
df.head()
# Out:
#    prov  dist  gapa  sex  agegrp provname  dname gapaname sexname agegrpname  \
# 0     0     0     0    0       0    NEPAL  NEPAL    NEPAL   Total      Total
# 1     0     0     0    0       1    NEPAL  NEPAL    NEPAL   Total    05 Year
# 2     0     0     0    0       2    NEPAL  NEPAL    NEPAL   Total    06 Year
# 3     0     0     0    0       3    NEPAL  NEPAL    NEPAL   Total    07 Year
# 4     0     0     0    0       4    NEPAL  NEPAL    NEPAL   Total    08 Year
#
#    rowtotal  a_readwrite  b_readonly  c_noreadwrite  d_notstd
# 0  26725295     20377980      114331        6223061      9923
# 1    568365       465615        7990          91618      3142
# 2    562745       499890        6313          55555       987
# 3    534278       494401        4245          35157       475
# 4    599728       560722        3287          35365       354

# %%
df.tail()
# Out:
#        prov  dist  gapa  sex  agegrp      provname       dname       gapaname  \
# 68620     7    77    99    2      20  Sudurpaschim  Kanchanpur  INSTITUTIONAL
# 68621     7    77    99    2      21  Sudurpaschim  Kanchanpur  INSTITUTIONAL
# 68622     7    77    99    2      22  Sudurpaschim  Kanchanpur  INSTITUTIONAL
# 68623     7    77    99    2      23  Sudurpaschim  Kanchanpur  INSTITUTIONAL
# 68624     7    77    99    2      24  Sudurpaschim  Kanchanpur  INSTITUTIONAL
#
#       sexname     agegrpname  rowtotal  a_readwrite  b_readonly  \
# 68620  Female  55 - 59 Years         1            0           0
# 68621  Female  60 - 64 Years         2            0           0
# 68622  Female  65 - 69 Years         1            0           0
# 68623  Female  70 - 74 Years         1            0           0
# 68624  Female      75+ Years         2            0           0
#
#        c_noreadwrite  d_notstd
# 68620              1         0
# 68621              2         0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68625 entries, 0 to 68624
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   prov           68625 non-null  int64
#  1   dist           68625 non-null  int64
#  2   gapa           68625 non-null  int64
#  3   sex            68625 non-null  int64
#  4   agegrp         68625 non-null  int64
#  5   provname       68625 non-null  object
#  6   dname          68625 non-null  object
#  7   gapaname       68625 non-null  object
#  8   sexname        68625 non-null  object
#  9   agegrpname     68625 non-null  object
#  10  rowtotal       68625 non-null  int64
#  11  a_readwrite    68625 non-null  int64
#  12  b_readonly     68625 non-null  int64
#  13  c_noreadwrite  68625 non-null  int64
#  14  d_notstd       68625 non-null  int64
# dtypes: int64(10), object(5)
# memory usage: 7.9+ MB

# %%
df.describe()
# Out:
#                prov          dist          gapa           sex        agegrp  \
# count  68625.000000  68625.000000  68625.000000  68625.000000  68625.000000
# mean       3.673224     36.906011     13.315847      1.000000     12.000000
# std        2.002006     22.559762     26.271365      0.816503      7.211155
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        2.000000     17.000000      2.000000      0.000000      6.000000
# 50%        3.000000     34.000000      5.000000      1.000000     12.000000
# 75%        5.000000     56.000000      9.000000      2.000000     18.000000
# max        7.000000     77.000000     99.000000      2.000000     24.000000
#
#            rowtotal   a_readwrite     b_readonly  c_noreadwrite      d_notstd
# count  6.862500e+04  6.862500e+04   68625.000000   6.862500e+04  68625.000000
# mean   6.231034e+03  4.751150e+03      26.656408   1.450914e+03      2.313559
# ...

# %%
df.isnull().sum()
# Out:
# prov             0
# dist             0
# gapa             0
# sex              0
# agegrp           0
# provname         0
# dname            0
# gapaname         0
# sexname          0
# agegrpname       0
# rowtotal         0
# a_readwrite      0
# b_readonly       0
# c_noreadwrite    0
# d_notstd         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (68625, 15)

# %%
df['agegrpname'].unique()
# Out:
# array(['Total', '05 Year', '06 Year', '07 Year', '08 Year', '09 Year',
#        '10 Year', '11 Year', '12 Year', '13 Year', '14 Year', '15 Year',
#        '16 - 19 Years', '20 - 24 Years', '25 - 29 Years', '30 - 34 Years',
#        '35 - 39 Years', '40 - 44 Years', '45 - 49 Years', '50 - 54 Years',
#        '55 - 59 Years', '60 - 64 Years', '65 - 69 Years', '70 - 74 Years',
#        '75+ Years'], dtype=object)

# %%
age_groups_to_drop = [
    '05 Year', '06 Year', '07 Year', '08 Year', '09 Year', '10 Year',
    '11 Year', '12 Year', '13 Year', '14 Year', '15 Year',
    '16 - 19 Years', '20 - 24 Years', '25 - 29 Years', '30 - 34 Years',
    '35 - 39 Years', '40 - 44 Years', '45 - 49 Years', '50 - 54 Years',
    '55 - 59 Years', '60 - 64 Years', '65 - 69 Years', '70 - 74 Years',
    '75+ Years'
]
# Drop rows where agegrpname is in the list
df = df[~df['agegrpname'].isin(age_groups_to_drop)]
df['agegrpname'].unique()
# Out:
# array(['Total'], dtype=object)

# %%
df.shape
# Out:
# (2745, 15)

# %%
# Drop the agegrpname column
df = df.drop('agegrpname', axis=1)

# %%
df = df.rename(columns={
    'rowtotal': 'total',
    'a_readwrite': 'can read & write',
    'b_readonly': 'can read only',
    'c_noreadwrite': 'cant read & write',
    'd_notstd': 'not stated',
    'dname': 'district',
    'provname': 'province'
})

# %%
df.columns
# Out:
# Index(['prov', 'dist', 'gapa', 'sex', 'agegrp', 'province', 'district',
#        'gapaname', 'sexname', 'total', 'can read & write', 'can read only',
#        'cant read & write', 'not stated'],
#       dtype='object')

# %%
df['gapaname'].unique()
# Out:
# array(['NEPAL', 'PROVINCE - 1', 'Taplejung (TOTAL)',
#        'Phaktanlung Gaunpalika', 'Mikwakhola Gaunpalika',
#        'Meringden Gaunpalika', 'Maiwakhola Gaunpalika',
#        'Aatharai Tribeni Gaunpalika', 'Phungling Municipality',
#        'Pathivara Yangwarak Gaunpalika', 'Sirijanga Gaunpalika',
#        'Sidingba Gaunpalika', 'INSTITUTIONAL', 'Sankhuwasabha (TOTAL)',
#        'Bhotkhola Gaunpalika', 'Makalu Gaunpalika',
#        'Silichong Gaunpalika', 'Chichila Gaunpalika',
#        'Sabhapokhari Gaunpalika', 'Khandabari Municipality',
#        'Panchakhapan Municipality', 'Chainapur Municipality',
#        'Madi Municipality', 'Dharmadevi Municipality',
#        'Solukhumbu (TOTAL)', 'Khumbu Pasanglhamu Gaunpalika',
#        'Mahakulung Gaunpalika', 'Sotang Gaunpalika',
#        'Mapya Dudhkoshi Gaunpalika', 'Thulung Dudhkoshi Gaunpalika',
#        'Necha Salyan Gaunpalika', 'Solu Dhudhakunda Municipality',
#        'Likhu Pike Gaunpalika', 'Okhaldhunga (TOTAL)',
# ...

# %%
# Drop rows where gapaname is 'INSTITUTIONAL' (case-insensitive)
df = df[df['gapaname'].str.lower() != 'institutional']

# %%
df['district'].unique()
# Out:
# array(['NEPAL', 'PROVINCE - 1', 'TAPLEJUNG', 'Taplejung', 'SANKHUWASABHA',
#        'Sankhuwasabha', 'SOLUKHUMBU', 'Solukhumbu', 'OKHALDHUNGA',
#        'Okhaldhunga', 'KHOTANG', 'Khotang', 'BHOJPUR', 'Bhojpur',
#        'DHANKUTA', 'Dhankuta', 'TERHATHUM', 'Terhathum', 'PANCHTHAR',
#        'Panchthar', 'ILAM', 'Ilam', 'JHAPA', 'Jhapa', 'MORANG', 'Morang',
#        'SUNSARI', 'Sunsari', 'UDAYAPUR', 'Udayapur', 'MADHESH', 'SAPTARI',
#        'Saptari', 'SIRAHA', 'Siraha', 'DHANUSA', 'Dhanusa', 'MAHOTTARI',
#        'Mahottari', 'SARLAHI', 'Sarlahi', 'RAUTAHAT', 'Rautahat', 'BARA',
#        'Bara', 'PARSA', 'Parsa', 'BAGMATI', 'DOLAKHA', 'Dolakha',
#        'SINDHUPALCHOK', 'Sindhupalchok', 'RASUWA', 'Rasuwa', 'DHADING',
#        'Dhading', 'NUWAKOT', 'Nuwakot', 'KATHMANDU', 'Kathmandu',
#        'BHAKTAPUR', 'Bhaktapur', 'LALITPUR', 'Lalitpur', 'KAVREPALANCHOK',
#        'Kavrepalanchok', 'RAMECHHAP', 'Ramechhap', 'SINDHULI', 'Sindhuli',
# ...

# %%
df['province'].unique()
# Out:
# array(['NEPAL', 'PROVINCE - 1', 'Province-1', 'MADHESH', 'Madhesh',
#        'BAGMATI', 'Bagmati', 'GANDAKI', 'Gandaki', 'LUMBINI', 'Lumbini',
#        'KARNALI', 'Karnali', 'SUDURPASCHIM', 'Sudurpaschim'], dtype=object)

# %%
taplejung_df = df[df['district'].str.lower() == 'taplejung']
taplejung_df
# Out:
#      prov  dist  gapa  sex  agegrp    province   district  \
# 150     1     1     0    0       0  Province-1  TAPLEJUNG
# 175     1     1     0    1       0  Province-1  TAPLEJUNG
# 200     1     1     0    2       0  Province-1  TAPLEJUNG
# 225     1     1     1    0       0  Province-1  Taplejung
# 250     1     1     1    1       0  Province-1  Taplejung
# 275     1     1     1    2       0  Province-1  Taplejung
# 300     1     1     2    0       0  Province-1  Taplejung
# 325     1     1     2    1       0  Province-1  Taplejung
# 350     1     1     2    2       0  Province-1  Taplejung
# 375     1     1     3    0       0  Province-1  Taplejung
# 400     1     1     3    1       0  Province-1  Taplejung
# 425     1     1     3    2       0  Province-1  Taplejung
# 450     1     1     4    0       0  Province-1  Taplejung
# 475     1     1     4    1       0  Province-1  Taplejung
# 500     1     1     4    2       0  Province-1  Taplejung
# ...

# %%
# Convert all values in 'District Name' column to lowercase
df['district'] = df['district'].str.lower()
df['province'] = df['province'].str.lower()

# %%
# Create a 'rural_urban' column
df['rural/urban'] = df['gapaname'].apply(lambda x: 'Urban' if 'Municipality' in x
                                         else ('Rural' if 'Gaunpalika' in x else 'Total(Urban+Rural)'))

# %%
taplejung_df = df[df['district'].str.lower() == 'taplejung']
taplejung_df
# Out:
#      prov  dist  gapa  sex  agegrp    province   district  \
# 150     1     1     0    0       0  province-1  taplejung
# 175     1     1     0    1       0  province-1  taplejung
# 200     1     1     0    2       0  province-1  taplejung
# 225     1     1     1    0       0  province-1  taplejung
# 250     1     1     1    1       0  province-1  taplejung
# 275     1     1     1    2       0  province-1  taplejung
# 300     1     1     2    0       0  province-1  taplejung
# 325     1     1     2    1       0  province-1  taplejung
# 350     1     1     2    2       0  province-1  taplejung
# 375     1     1     3    0       0  province-1  taplejung
# 400     1     1     3    1       0  province-1  taplejung
# 425     1     1     3    2       0  province-1  taplejung
# 450     1     1     4    0       0  province-1  taplejung
# 475     1     1     4    1       0  province-1  taplejung
# 500     1     1     4    2       0  province-1  taplejung
# ...

# %%
agg_cols =['total', 'can read & write', 'can read only', 'cant read & write','not stated']
df = df.groupby(
    ['province', 'district', 'rural/urban', 'sexname'],
    sort=False
)[agg_cols].sum().reset_index()

# %%
taplejung_df = df[df['district'].str.lower() == 'taplejung']
taplejung_df
# Out:
#       province   district         rural/urban sexname   total  \
# 6   province-1  taplejung  Total(Urban+Rural)   Total  110370
# 7   province-1  taplejung  Total(Urban+Rural)    Male   55530
# 8   province-1  taplejung  Total(Urban+Rural)  Female   54840
# 9   province-1  taplejung               Rural   Total   83122
# 10  province-1  taplejung               Rural    Male   41684
# 11  province-1  taplejung               Rural  Female   41438
# 12  province-1  taplejung               Urban   Total   26112
# 13  province-1  taplejung               Urban    Male   12739
# 14  province-1  taplejung               Urban  Female   13373
#
#     can read & write  can read only  cant read & write  not stated
# 6              90733            341              19295           1
# 7              48965            162               6403           0
# 8              41768            179              12892           1
# 9              67042            292              15787           1
# ...

# %%
df.head()
# Out:
#        province      district         rural/urban sexname     total  \
# 0         nepal         nepal  Total(Urban+Rural)   Total  26725295
# 1         nepal         nepal  Total(Urban+Rural)    Male  12963026
# 2         nepal         nepal  Total(Urban+Rural)  Female  13762269
# 3  province - 1  province - 1  Total(Urban+Rural)   Total   4578440
# 4  province - 1  province - 1  Total(Urban+Rural)    Male   2218709
#
#    can read & write  can read only  cant read & write  not stated
# 0          20377980         114331            6223061        9923
# 1          10830886          43921            2083529        4690
# 2           9547094          70410            4139532        5233
# 3           3648225          11469             918528         218
# 4           1910756           4793             303064          96

# %%
for col in df.select_dtypes(include='object').columns:
    print(f"Unique values in '{col}':")
    print(df[col].unique())
    print("-" * 40)
# Out:
# Unique values in 'province':
# ['nepal' 'province - 1' 'province-1' 'madhesh' 'bagmati' 'gandaki'
#  'lumbini' 'karnali' 'sudurpaschim']
# ----------------------------------------
# Unique values in 'district':
# ['nepal' 'province - 1' 'taplejung' 'sankhuwasabha' 'solukhumbu'
#  'okhaldhunga' 'khotang' 'bhojpur' 'dhankuta' 'terhathum' 'panchthar'
#  'ilam' 'jhapa' 'morang' 'sunsari' 'udayapur' 'madhesh' 'saptari' 'siraha'
#  'dhanusa' 'mahottari' 'sarlahi' 'rautahat' 'bara' 'parsa' 'bagmati'
#  'dolakha' 'sindhupalchok' 'rasuwa' 'dhading' 'nuwakot' 'kathmandu'
#  'bhaktapur' 'lalitpur' 'kavrepalanchok' 'ramechhap' 'sindhuli'
#  'makwanpur' 'chitawan' 'gandaki' 'gorkha' 'manang' 'mustang' 'myagdi'
#  'kaski' 'lamjung' 'tanahu' 'nawalparasi (bardaghat susta east)' 'syangja'
#  'parbat' 'baglung' 'lumbini' 'rukum (east)' 'rolpa' 'pyuthan' 'gulmi'
#  'arghakhanchi' 'palpa' 'nawalparasi (bardaghat susta west)' 'rupandehi'
# ...

# %%
# Replace 'province - 1' with 'Province-1' in the Province Name column
df['province'] = df['province'].replace('province - 1', 'province-1')
df['sexname'] = df['sexname'].replace('Total', 'Total(Male+Female)')

# %%
for col in df.select_dtypes(include='object').columns:
    print(f"Unique values in '{col}':")
    print(df[col].unique())
    print("-" * 40)
# Out:
# Unique values in 'province':
# ['nepal' 'province-1' 'madhesh' 'bagmati' 'gandaki' 'lumbini' 'karnali'
#  'sudurpaschim']
# ----------------------------------------
# Unique values in 'district':
# ['nepal' 'province - 1' 'taplejung' 'sankhuwasabha' 'solukhumbu'
#  'okhaldhunga' 'khotang' 'bhojpur' 'dhankuta' 'terhathum' 'panchthar'
#  'ilam' 'jhapa' 'morang' 'sunsari' 'udayapur' 'madhesh' 'saptari' 'siraha'
#  'dhanusa' 'mahottari' 'sarlahi' 'rautahat' 'bara' 'parsa' 'bagmati'
#  'dolakha' 'sindhupalchok' 'rasuwa' 'dhading' 'nuwakot' 'kathmandu'
#  'bhaktapur' 'lalitpur' 'kavrepalanchok' 'ramechhap' 'sindhuli'
#  'makwanpur' 'chitawan' 'gandaki' 'gorkha' 'manang' 'mustang' 'myagdi'
#  'kaski' 'lamjung' 'tanahu' 'nawalparasi (bardaghat susta east)' 'syangja'
#  'parbat' 'baglung' 'lumbini' 'rukum (east)' 'rolpa' 'pyuthan' 'gulmi'
#  'arghakhanchi' 'palpa' 'nawalparasi (bardaghat susta west)' 'rupandehi'
#  'kapilbastu' 'dang' 'banke' 'bardiya' 'karnali' 'dolpa' 'mugu' 'humla'
# ...

# %%
# Calculate literacy rate: ((can read and write + can read only) / Total) * 100
df['literacy rate'] = ((df['can read & write'] + df['can read only']) / df['total']) * 100

# %%
df.head()
# Out:
#      province      district         rural/urban             sexname     total  \
# 0       nepal         nepal  Total(Urban+Rural)  Total(Male+Female)  26725295
# 1       nepal         nepal  Total(Urban+Rural)                Male  12963026
# 2       nepal         nepal  Total(Urban+Rural)              Female  13762269
# 3  province-1  province - 1  Total(Urban+Rural)  Total(Male+Female)   4578440
# 4  province-1  province - 1  Total(Urban+Rural)                Male   2218709
#
#    can read & write  can read only  cant read & write  not stated  \
# 0          20377980         114331            6223061        9923
# 1          10830886          43921            2083529        4690
# 2           9547094          70410            4139532        5233
# 3           3648225          11469             918528         218
# 4           1910756           4793             303064          96
#
#    literacy rate
# 0      76.677586
# 1      83.890960
# 2      69.883128
# 3      79.933209
# ...

# %%
numerical_cols = df.select_dtypes(include=['number']).columns
def detect_outliers_iqr(column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower) | (df[column] > upper)]
    return outliers
for col in numerical_cols:
    outliers = detect_outliers_iqr(col)
    print(f"Outliers found in {col}: {len(outliers)}")
# Out:
# Outliers found in total: 78
# Outliers found in can read & write: 81
# Outliers found in can read only: 68
# Outliers found in cant read & write: 80
# Outliers found in not stated: 69
# Outliers found in literacy rate: 5

# %%
# #Exporting new dataset
df.to_csv('/content/drive/MyDrive/dataset/V2nepal_education_cleaned_dataset.csv', index=False)
